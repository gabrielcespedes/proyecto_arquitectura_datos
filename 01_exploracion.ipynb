# %% [markdown]
# # Datos e-commerce

# %%
import pandas as pd

# %%
df_ecommerce = pd.read_csv("data/data_ecommerce.csv", encoding = "latin1", sep = ",")
df_ecommerce.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # **Datos Minería de Procesos**

# %%
df_process = pd.read_csv("data/incident_management.csv", sep = ";")
df_process.head()
# Out:
#    Case ID    Variant Priority Reporter         Timestamp  \
# 0  INC0001  Variant 4   Medium    Alice  17/11/2023 11:17
# 1  INC0001  Variant 4   Medium    Alice  17/11/2023 13:30
# 2  INC0001  Variant 4   Medium    Alice  17/11/2023 14:06
# 3  INC0001  Variant 4   Medium    Alice  17/11/2023 16:52
# 4  INC0001  Variant 4   Medium    Alice  17/11/2023 18:07
#
#                                   Event         Issue Type Resolver  \
# 0                        Ticket created  Performance Issue      NaN
# 1    Ticket assigned to level 1 support  Performance Issue      Sam
# 2                 WIP - level 1 support  Performance Issue      Sam
# 3  Level 1 escalates to level 2 support  Performance Issue  Michael
# 4                 WIP - level 2 support  Performance Issue     Emma
#
#   Report Channel  Short Description  Customer Satisfaction
# 0        Website  Application crash                      3
# 1        Website  Application crash                      3
# ...

# %%
# minería de procesos
# dataset ==> event_log
# evento: me detalla alguna tarea (o actividad o etapa) de un caso específico de un proceso.

# %%
len(df_process)
# Out:
# 242901

# %%
# 242901 ==> eventos

# %%
len(df_process["Case ID"].unique())
# Out:
# 31588

# %%
# 31588 tickets (Casos)

# %%
len(df_process["Variant"].unique())
# Out:
# 13

# %%
df_process["Variant"].value_counts()
# Out:
# Variant
# Variant 3     95208
# Variant 1     59376
# Variant 7     18915
# Variant 4     15638
# Variant 5     14256
# Variant 8      9540
# Variant 6      7180
# Variant 9      6250
# Variant 11     3756
# Variant 2      3736
# Variant 10     3636
# Variant 13     3388
# Variant 12     2022
# Name: count, dtype: int64

# %%
df_process[df_process["Variant"] == "Variant 3"].head()
# Out:
#     Case ID    Variant Priority Reporter         Timestamp  \
# 7   INC0002  Variant 3     High  Charlie   15/08/2023 7:08
# 8   INC0002  Variant 3     High  Charlie   15/08/2023 8:29
# 9   INC0002  Variant 3     High  Charlie   15/08/2023 8:39
# 10  INC0002  Variant 3     High  Charlie  15/08/2023 10:11
# 11  INC0002  Variant 3     High  Charlie  15/08/2023 10:46
#
#                                    Event         Issue Type Resolver  \
# 7                         Ticket created  Performance Issue      NaN
# 8     Ticket assigned to level 1 support  Performance Issue      Sam
# 9                  WIP - level 1 support  Performance Issue      Sam
# 10  Level 1 escalates to level 2 support  Performance Issue    Sarah
# 11                 WIP - level 2 support  Performance Issue     Emma
#
#    Report Channel Short Description  Customer Satisfaction
# 7             App   Data loss issue                      3
# 8             App   Data loss issue                      3
# ...

# %%
# Variante más frecuente

# %%
df_process[df_process["Case ID"] == "INC0002"]
# Out:
#     Case ID    Variant Priority Reporter         Timestamp  \
# 7   INC0002  Variant 3     High  Charlie   15/08/2023 7:08
# 8   INC0002  Variant 3     High  Charlie   15/08/2023 8:29
# 9   INC0002  Variant 3     High  Charlie   15/08/2023 8:39
# 10  INC0002  Variant 3     High  Charlie  15/08/2023 10:11
# 11  INC0002  Variant 3     High  Charlie  15/08/2023 10:46
# 12  INC0002  Variant 3     High  Charlie  15/08/2023 12:28
# 13  INC0002  Variant 3     High  Charlie  15/08/2023 12:46
# 14  INC0002  Variant 3     High  Charlie  15/08/2023 12:51
#
#                                    Event         Issue Type Resolver  \
# 7                         Ticket created  Performance Issue      NaN
# 8     Ticket assigned to level 1 support  Performance Issue      Sam
# 9                  WIP - level 1 support  Performance Issue      Sam
# 10  Level 1 escalates to level 2 support  Performance Issue    Sarah
# 11                 WIP - level 2 support  Performance Issue     Emma
# ...

# %%
# Variante menos frecuente

# %%
df_process[df_process["Variant"] == "Variant 12"].iloc[0]
# Out:
# Case ID                           INC0087
# Variant                        Variant 12
# Priority                              Low
# Reporter                             John
# Timestamp                04/04/2023 17:13
# Event                      Ticket created
# Issue Type                            Bug
# Resolver                              NaN
# Report Channel                      Email
# Short Description               UI glitch
# Customer Satisfaction                   4
# Name: 689, dtype: object

# %%
df_process[df_process["Case ID"] == "INC0087"]
# Out:
#      Case ID     Variant Priority Reporter         Timestamp  \
# 689  INC0087  Variant 12      Low     John  04/04/2023 17:13
# 690  INC0087  Variant 12      Low     John   05/04/2023 0:25
# 691  INC0087  Variant 12      Low     John   05/04/2023 3:07
# 692  INC0087  Variant 12      Low     John  05/04/2023 11:51
# 693  INC0087  Variant 12      Low     John  05/04/2023 13:22
# 694  INC0087  Variant 12      Low     John  05/04/2023 14:56
#
#                                   Event Issue Type Resolver Report Channel  \
# 689                      Ticket created        Bug      NaN          Email
# 690  Ticket assigned to level 2 support        Bug    Sarah          Email
# 691               WIP - level 2 support        Bug    Sarah          Email
# 692    Ticket solved by level 2 support        Bug     Emma          Email
# 693          Customer feedback received        Bug      NaN          Email
# 694                       Ticket closed        Bug      NaN          Email
#
# ...

# %% [markdown]
# # **Dataset Mantenimiento**

# %%
df_maintenance = pd.read_csv("data/predictive_maintenance.csv")
df_maintenance.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure
